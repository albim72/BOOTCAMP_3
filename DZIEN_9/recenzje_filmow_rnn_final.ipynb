# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence

# %%
#parametry modelu i treningu
max_features = 10000
max_len = 500
batch_size = 32
embedding_dims = 50
units = 32
epochs = 5

# %%
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=max_features)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step

# %%
#dostosowywanie recenzji do stałej długości
x_train = sequence.pad_sequences(x_train,maxlen=max_len)
x_test = sequence.pad_sequences(x_test,maxlen=max_len)

# %%
model = Sequential([
    layers.Embedding(max_features,embedding_dims,input_length=max_len),
    layers.LSTM(units),
    layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# 782/782 [==============================] - 177s 223ms/step - loss: 0.4246 - accuracy: 0.8048 - val_loss: 0.3513 - val_accuracy: 0.8545
# Epoch 2/5
# 782/782 [==============================] - 173s 221ms/step - loss: 0.2532 - accuracy: 0.9014 - val_loss: 0.2977 - val_accuracy: 0.8792
# Epoch 3/5
# 782/782 [==============================] - 172s 220ms/step - loss: 0.1793 - accuracy: 0.9325 - val_loss: 0.3245 - val_accuracy: 0.8739
# Epoch 4/5
# 782/782 [==============================] - 444s 568ms/step - loss: 0.1527 - accuracy: 0.9446 - val_loss: 0.3656 - val_accuracy: 0.8746
# Epoch 5/5
# 782/782 [==============================] - 496s 635ms/step - loss: 0.1125 - accuracy: 0.9606 - val_loss: 0.3936 - val_accuracy: 0.8617

# %%
loss, accuracy = model.evaluate(x_test,y_test,batch_size=batch_size)
print(f'Accuracy: {accuracy}')
# Out:
# 782/782 [==============================] - 90s 114ms/step - loss: 0.3936 - accuracy: 0.8617
# Accuracy: 0.8617200255393982

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
recenzje = [
    "The movie was great!",
    "The film was okay...",
    "The movie was terrible",
    "Very bad movie!",
    "Big shit!",
    "Disaster",
    "Beautiful disaster",
    "Bardzo głupi film",
    "Bardzo głupi film, Bardzo głupi film, Bardzo głupi film, Bardzo głupi film, Bardzo głupi film!",
    "The movie is wonderful, director is a genius",
    "The film is a terrible,zero talent,class E cinema!",
    "The film is good but far from perfection.",
    "The film is very medicore.",
    "The film is very medicore.The film is good but far from perfection. The director is a klutz"
]

# %%
#przetwarzanie recenzji do formatu zgodnego z modelem
word_index = imdb.get_word_index()
sequences = [[word_index[word] for word in review.split() if word in word_index] for review in recenzje]
sequences = pad_sequences(sequences,maxlen=max_len)

predictions = model.predict(sequences)
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 2 in <module>
# NameError: name 'imdb' is not defined

# %%
#klasyfikacja sentymentu
sentiment_label = ['Negative','Positive']
for i, prediction in enumerate(predictions):
    sentiment = prediction
    print(f'recenzja: {recenzje[i]} -> ocena: {sentiment}\n')
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 3 in <module>
# NameError: name 'predictions' is not defined
